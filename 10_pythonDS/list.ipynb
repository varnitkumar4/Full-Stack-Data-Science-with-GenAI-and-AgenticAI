# %% [markdown]
# # List Datastructure

# %%
l =[] # this is a empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l.append(20,30)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [10,3.4,"ram",True,3+5j]
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j)]

# %%
l1.append([2,3,4])

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# [10, 20, 30, 40, 50, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 1931959527296
# 1931960030848

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# [10, 20, 30, 40, 50, 10]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# []

# %%
del l3

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 print(l)
#       2 print(l1)
# ----> 3 print(l3)
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l.count(20)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l.index(10)
# Out:
# 0

# %%
l1.index("ram")
# Out:
# 2

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l1[3:]
# Out:
# [True, (3+5j), [2, 3, 4]]

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l1[2]
# Out:
# 'ram'

# %%
print(l1[2][0])
print(l1[2][1])
print(l1[2][2])
# Out:
# r
# a
# m

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l1[0]=100

# %%
l1
# Out:
# [100, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l2 = [10,20,30]
l2
# Out:
# [10, 20, 30]

# %%
l2[0] = 100
l2
# Out:
# [100, 20, 30]

# %%
l2.insert(2,25)
l2
# Out:
# [100, 20, 25, 30]

# %%
l2.insert(2,[1,2,3])
l2
# Out:
# [100, 20, [1, 2, 3], 25, 30]

# %%
l2.pop()
# Out:
# 30

# %%
l2
# Out:
# [100, 20, [1, 2, 3], 25]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l.pop(-2)
# Out:
# (3+5j)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, 'ram', True, [2, 3, 4]]

# %%
l.remove("ram")

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, True, [2, 3, 4]]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, True, [2, 3, 4]]
# [100, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# [100, 20, [1, 2, 3], 25]

# %%
l.reverse()

# %%
l
# Out:
# [[2, 3, 4], True, 3.4, 10, 10, 50, 40, 30, 20, 10]

# %%
l3 = ['a','b','c']
print(l3)
l3.reverse()
l3
# Out:
# ['a', 'b', 'c']
# ['c', 'b', 'a']

# %%
l
# Out:
# [[2, 3, 4], True, 3.4, 10, 10, 50, 40, 30, 20, 10]

# %%
l4 = [6,4,7,9,2,5,6]
print(l4)
l4.sort()
print(l4)
# Out:
# [6, 4, 7, 9, 2, 5, 6]
# [2, 4, 5, 6, 6, 7, 9]

# %%
l4 = [6,8,7,9,2,11,6]
print(l4)
l4.sort(reverse=True)
print(l4)
# Out:
# [6, 8, 7, 9, 2, 11, 6]
# [11, 9, 8, 7, 6, 6, 2]

# %%
l
# Out:
# [[2, 3, 4], True, 3.4, 10, 10, 50, 40, 30, 20, 10]

# %%
10 in l
# Out:
# True

# %%
for i in l:
    print(i)
# Out:
# [2, 3, 4]
# True
# 3.4
# 10
# 10
# 50
# 40
# 30
# 20
# 10

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, [2, 3, 4])
# (1, True)
# (2, 3.4)
# (3, 10)
# (4, 10)
# (5, 50)
# (6, 40)
# (7, 30)
# (8, 20)
# (9, 10)

# %%
l4
# Out:
# [11, 9, 8, 7, 6, 6, 2]

# %%
all(l4)
# Out:
# True

# %%
l4.append(0)

# %%
all(l4)
# Out:
# False
