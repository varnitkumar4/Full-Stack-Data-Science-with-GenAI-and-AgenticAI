# %%
t = ()
print(t)
print(type(t))
# Out:
# ()
# <class 'tuple'>

# %%
t1 = (10,True,6.7,1+2j,"welcome")
t1
# Out:
# (10, True, 6.7, (1+2j), 'welcome')

# %%
t1[0]
# Out:
# 10

# %%
t1.count(10)
# Out:
# 1

# %%
# del t1

# %%
t1
# Out:
# (10, True, 6.7, (1+2j), 'welcome')

# %%
t = (1,2,3,4,5,5,7)
t
# Out:
# (1, 2, 3, 4, 5, 5, 7)

# %%
t * 2
# Out:
# (1, 2, 3, 4, 5, 5, 7, 1, 2, 3, 4, 5, 5, 7)
