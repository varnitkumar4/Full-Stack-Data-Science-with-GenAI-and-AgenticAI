# %% [markdown]
# # input()

# %%
x = input()
x
# Out:
# '5'

# %%
x = input()
y = input()
print(x+y)
# input take a input as a string
# Out:
# 22

# %%
x = int(input())
y = int(input())
print(x+y)
# Out:
# 10

# %%
x = int(input("enter first number"))
y = int(input("enter second number"))
print(f"addition of {x} + {y} = ",x+y)
# Out:
# addition of 8 + 5 =  13

# %% [markdown]
# # input functin with string

# %%
st = input("enter a string")[0]
print(st)
# Out:
# g

# %%
st = input("enter a string")[1]
print(st)
# Out:
# g

# %%
st = input("enter a string")[8:]
print(st)
# Out:
# 9123

# %% [markdown]
# # input function with expration

# %%
result = eval(input("enter an expr"))
result
# Out:
# 10
