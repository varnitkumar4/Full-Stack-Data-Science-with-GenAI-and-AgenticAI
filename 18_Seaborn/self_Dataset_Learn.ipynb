# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-20b582fb-24c2-4934-ad6f-4426cf88d287" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20b582fb-24c2-4934-ad6f-4426cf88d287">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Q1**
# # **Load the dataset using Pandas and convert the salary column into a NumPy array.**

# %%
df = pd.read_csv("employee_sales_learning_dataset.csv")
df.head()
# Out:
#   Employee_ID          Name Department       City  Gender   Age  \
# 0       E0001  Employee_001         IT       Pune    Male  37.0
# 1       E0002  Employee_002  Marketing       Pune  Female  39.0
# 2       E0003  Employee_003    Finance  Hyderabad    Male  30.0
# 3       E0004  Employee_004         HR     Mumbai    Male  37.0
# 4       E0005  Employee_005      Sales  Bengaluru  Female  39.0
#
#    Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 0                 7   69600.0        87400.0                 3.8
# 1                15   94100.0       104800.0                 2.5
# 2                 1   37300.0        56100.0                 3.2
# 3                11   78700.0        37600.0                 3.8
# 4                14  105500.0       148100.0                 3.2
#
#    Projects_Completed  Attendance_Percent Joining_Date
# 0                  10                86.1   2018-06-20
# 1                   9                98.0   2024-09-22
# ...

# %%
df.shape
# Out:
# (253, 13)

# %%
salary_array = df["Salary"].to_numpy()

print(salary_array.dtype)
# Out:
# float64

# %%
salary_array
# Out:
# array([ 69600.,  94100.,  37300.,  78700., 105500.,  69900.,  62300.,
#         80600.,  75200.,  43300.,  45000.,  64500.,  39800.,  85600.,
#         45800.,  77800.,  46600.,  51000.,  87000.,  59800.,  91500.,
#         91800.,  75700.,  75100.,  55900.,     nan, 102100., 101400.,
#         48500.,  92700.,  42000.,  64000.,  99200.,  46600.,  79800.,
#         52200.,  66900.,  65000., 103500.,  84700.,  50200.,  62400.,
#         31200.,  32100.,  31200., 101400., 102300.,  92100.,  48300.,
#         97800.,  48300.,  47000.,  57000.,  49600.,  32000.,  63900.,
#        101800.,  81600.,  96700.,  77500.,  79600.,  45900.,  25000.,
#         57100.,  85400.,  45500.,  75200.,  67100.,  29600.,  90600.,
#         28100.,  73200.,  58100.,  60600.,  48400.,  57600.,  66400.,
#         46800.,  46000., 100600.,  97300.,  85000.,  90600., 107000.,
#         85300.,  49100., 101900.,  72100.,  59000.,  67900.,  98300.,
# ...

# %% [markdown]
# Q2
# # **Using NumPy, calculate the following for the salary:Mean Median Minimum Maximum**

# %%
print(np.nanmean(salary_array))
print(np.nanmedian(salary_array))
print(np.nanmin(salary_array))
print(np.nanmax(salary_array))
# Out:
# 69382.52032520325
# 69850.0
# 25000.0
# 113600.0

# %% [markdown]
# # **Q3. Create a NumPy array for `monthly_sales` and determine:How many employees have monthly sales greater than 100,000?**

# %%
monthly_sales = df["Salary"].to_numpy()

count = np.sum(monthly_sales > 100000)

print(count)

# 24 employees whose salary is grater than 100000
# Out:
# 24

# %% [markdown]
# # **Q4. Using the `performance_rating` NumPy array:How many employees have a rating of 4.0 or higher?**

# %%
Rating = df['Performance_Rating'].to_numpy()
count = np.sum(Rating >= 4.0)
print(count)

# 68 employees hav 4.0 nad more than 4.0 rating
# Out:
# 68

# %% [markdown]
# # **Q5. Calculate the standard deviation of the salary using NumPy.**

# %%
print(np.std(df['Salary']))
# Out:
# 21808.517657751265

# %%
np.nanstd(salary_array)  # nan lagaye hai ku ki usme nan value hai to usko chor ke std find karega
# Out:
# np.float64(21808.517657751265)

# %% [markdown]
# **Q6. Load the CSV into DataFrame.
# Find:
# number of rows
# number of columns
# column names
# data types**

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date
# 0                86.1   2018-06-20

# %%
print("row :",df.shape[0])
print("columns :",df.shape[1])
print("columns names:\n",df.columns)
print("datatype :\n",df.dtypes)
# Out:
# row : 253
# columns : 13
# columns names:
#  Index(['Employee_ID', 'Name', 'Department', 'City', 'Gender', 'Age',
#        'Experience_Years', 'Salary', 'Monthly_Sales', 'Performance_Rating',
#        'Projects_Completed', 'Attendance_Percent', 'Joining_Date'],
#       dtype='object')
# datatype :
#  Employee_ID            object
# Name                   object
# Department             object
# City                   object
# Gender                 object
# Age                   float64
# Experience_Years        int64
# Salary                float64
# Monthly_Sales         float64
# Performance_Rating    float64
# Projects_Completed      int64
# Attendance_Percent    float64
# Joining_Date           object
# dtype: object

# %% [markdown]
# # **Q7. View the first 5 rows and the last 5 rows of the dataset.**

# %%
df.head()
# Out:
#   Employee_ID          Name Department       City  Gender   Age  \
# 0       E0001  Employee_001         IT       Pune    Male  37.0
# 1       E0002  Employee_002  Marketing       Pune  Female  39.0
# 2       E0003  Employee_003    Finance  Hyderabad    Male  30.0
# 3       E0004  Employee_004         HR     Mumbai    Male  37.0
# 4       E0005  Employee_005      Sales  Bengaluru  Female  39.0
#
#    Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 0                 7   69600.0        87400.0                 3.8
# 1                15   94100.0       104800.0                 2.5
# 2                 1   37300.0        56100.0                 3.2
# 3                11   78700.0        37600.0                 3.8
# 4                14  105500.0       148100.0                 3.2
#
#    Projects_Completed  Attendance_Percent Joining_Date
# 0                  10                86.1   2018-06-20
# 1                   9                98.0   2024-09-22
# ...

# %%
df.tail()
# Out:
#     Employee_ID          Name Department     City  Gender   Age  \
# 248       E0249  Employee_249  Marketing    Delhi    Male  38.0
# 249       E0250  Employee_250  Marketing   Mumbai    Male  36.0
# 250       E0013  Employee_013  Marketing  Chennai  Female  29.0
# 251       E0058  Employee_058      Sales  Chennai  Female  44.0
# 252       E0144  Employee_144         IT   Mumbai  Female   NaN
#
#      Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 248                13  110100.0       103700.0                 3.5
# 249                10   67400.0        46000.0                 3.2
# 250                 2   39800.0        87600.0                 4.0
# 251                11   81600.0       195500.0                 3.8
# 252                14  101100.0       115600.0                 2.1
#
#      Projects_Completed  Attendance_Percent Joining_Date
# 248                   5                87.5   2024-07-02
# 249                   6                88.1   2024-01-11
# ...

# %% [markdown]
# # **Q8. View the summary of numerical columns using describe().**

# %%
df.describe()
# Out:
#               Age  Experience_Years         Salary  Monthly_Sales  \
# count  246.000000        253.000000     246.000000     245.000000
# mean    37.097561          7.442688   69382.520325   88346.530612
# std      7.066927          4.622417   21852.979514   45867.779038
# min     22.000000          0.000000   25000.000000    3000.000000
# 25%     32.000000          4.000000   50225.000000   56600.000000
# 50%     37.000000          7.000000   69850.000000   83000.000000
# 75%     42.000000         11.000000   85675.000000  109400.000000
# max     54.000000         15.000000  113600.000000  223500.000000
#
#        Performance_Rating  Projects_Completed  Attendance_Percent
# count          247.000000          253.000000          253.000000
# mean             3.578947            5.387352           87.504348
# std              0.604087            2.852206            6.756915
# min              1.400000            1.000000           68.200000
# ...

# %% [markdown]
# # **Q9. Find out:How many different departments are there in the dataset?**

# %%
df['Department'].nunique()
# Out:
# 5

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date
# 0                86.1   2018-06-20

# %% [markdown]
# # **Q10. How many employees are there in each department?**

# %%
df.groupby('Department')['Employee_ID'].count()
# Out:
# Department
# Finance      36
# HR           37
# IT           49
# Marketing    54
# Sales        77
# Name: Employee_ID, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Sales        77
# Marketing    54
# IT           49
# HR           37
# Finance      36
# Name: count, dtype: int64

# %% [markdown]
# # **Q11. Find only those employees whose: Age > 30**

# %%
df[df['Age']>30]
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 0         E0001  Employee_001         IT       Pune    Male  37.0
# 1         E0002  Employee_002  Marketing       Pune  Female  39.0
# 3         E0004  Employee_004         HR     Mumbai    Male  37.0
# 4         E0005  Employee_005      Sales  Bengaluru  Female  39.0
# 5         E0006  Employee_006      Sales  Hyderabad    Male  34.0
# ..          ...           ...        ...        ...     ...   ...
# 246       E0247  Employee_247         IT      Delhi  Female  47.0
# 247       E0248  Employee_248  Marketing  Hyderabad  Female  40.0
# 248       E0249  Employee_249  Marketing      Delhi    Male  38.0
# 249       E0250  Employee_250  Marketing     Mumbai    Male  36.0
# 251       E0058  Employee_058      Sales    Chennai  Female  44.0
#
#      Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 0                   7   69600.0        87400.0                 3.8
# ...

# %% [markdown]
# # **Q12. Employees find karo jinki: Salary > 80000**

# %%
df[df['Salary'] > 80000]
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 1         E0002  Employee_002  Marketing       Pune  Female  39.0
# 4         E0005  Employee_005      Sales  Bengaluru  Female  39.0
# 7         E0008  Employee_008  Marketing    Chennai    Male  41.0
# 13        E0014  Employee_014      Sales  Bengaluru    Male  33.0
# 18        E0019  Employee_019         IT  Hyderabad    Male  44.0
# ..          ...           ...        ...        ...     ...   ...
# 235       E0236  Employee_236    Finance     Mumbai  Female  41.0
# 246       E0247  Employee_247         IT      Delhi  Female  47.0
# 248       E0249  Employee_249  Marketing      Delhi    Male  38.0
# 251       E0058  Employee_058      Sales    Chennai  Female  44.0
# 252       E0144  Employee_144         IT     Mumbai  Female   NaN
#
#      Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 1                  15   94100.0       104800.0                 2.5
# ...

# %% [markdown]
# # **Q13. Sirf IT department ke employees find karo.**

# %%
df[df['Department'] == 'IT'].head(2)
# Out:
#    Employee_ID          Name Department       City Gender   Age  \
# 0        E0001  Employee_001         IT       Pune   Male  37.0
# 16       E0017  Employee_017         IT  Bengaluru   Male  29.0
#
#     Experience_Years   Salary  Monthly_Sales  Performance_Rating  \
# 0                  7  69600.0        87400.0                 3.8
# 16                 0  46600.0        56600.0                 3.5
#
#     Projects_Completed  Attendance_Percent Joining_Date
# 0                   10                86.1   2018-06-20
# 16                   1                88.3   2022-08-25

# %% [markdown]
# # **Q14. Find employees where: Experience_Years > 5 AND Salary > 70000**

# %%
df.query('Experience_Years > 5 and Salary > 70000')
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 1         E0002  Employee_002  Marketing       Pune  Female  39.0
# 3         E0004  Employee_004         HR     Mumbai    Male  37.0
# 4         E0005  Employee_005      Sales  Bengaluru  Female  39.0
# 7         E0008  Employee_008  Marketing    Chennai    Male  41.0
# 8         E0009  Employee_009         HR  Bengaluru    Male  34.0
# ..          ...           ...        ...        ...     ...   ...
# 238       E0239  Employee_239    Finance      Delhi    Male  32.0
# 246       E0247  Employee_247         IT      Delhi  Female  47.0
# 248       E0249  Employee_249  Marketing      Delhi    Male  38.0
# 251       E0058  Employee_058      Sales    Chennai  Female  44.0
# 252       E0144  Employee_144         IT     Mumbai  Female   NaN
#
#      Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 1                  15   94100.0       104800.0                 2.5
# ...

# %% [markdown]
# # **Q15. Find employees where:Performance_Rating >= 4 AND Attendance_Percent >= 90**

# %%
df.query("Performance_Rating >=4 and Attendance_Percent >= 90")
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 58        E0059  Employee_059      Sales    Chennai  Female  52.0
# 63        E0064  Employee_064         IT       Pune    Male  37.0
# 66        E0067  Employee_067      Sales      Delhi    Male  31.0
# 67        E0068  Employee_068  Marketing       Pune    Male  36.0
# 77        E0078  Employee_078      Sales      Delhi  Female  29.0
# 79        E0080  Employee_080      Sales    Chennai  Female  43.0
# 85        E0086  Employee_086         IT  Bengaluru    Male  37.0
# 107       E0108  Employee_108    Finance       Pune    Male  29.0
# 120       E0121  Employee_121  Marketing    Chennai    Male  39.0
# 149       E0150  Employee_150      Sales  Bengaluru  Female  22.0
# 157       E0158  Employee_158    Finance      Delhi  Female  39.0
# 175       E0176  Employee_176      Sales  Bengaluru  Female  50.0
# 188       E0189  Employee_189         HR     Mumbai  Female  53.0
# ...

# %% [markdown]
# # **Q16.Check karo har column me kitne missing values hain.**

# %%
df.isna().sum()
# Out:
# Employee_ID           0
# Name                  0
# Department            0
# City                  5
# Gender                0
# Age                   7
# Experience_Years      0
# Salary                7
# Monthly_Sales         8
# Performance_Rating    6
# Projects_Completed    0
# Attendance_Percent    0
# Joining_Date          0
# dtype: int64

# %% [markdown]
# # **Q17. Duplicate rows find karo.**

# %%
df.duplicated().value_counts()
# Out:
# False    250
# True       3
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#     Employee_ID          Name Department     City  Gender   Age  \
# 250       E0013  Employee_013  Marketing  Chennai  Female  29.0
# 251       E0058  Employee_058      Sales  Chennai  Female  44.0
# 252       E0144  Employee_144         IT   Mumbai  Female   NaN
#
#      Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 250                 2   39800.0        87600.0                 4.0
# 251                11   81600.0       195500.0                 3.8
# 252                14  101100.0       115600.0                 2.1
#
#      Projects_Completed  Attendance_Percent Joining_Date
# 250                   9                86.2   2022-09-02
# 251                   1                91.5   2019-01-28
# 252                   1                83.0   2020-05-19

# %% [markdown]
# # **Q18. Duplicate rows remove karo.**

# %%
df.drop_duplicates()
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 0         E0001  Employee_001         IT       Pune    Male  37.0
# 1         E0002  Employee_002  Marketing       Pune  Female  39.0
# 2         E0003  Employee_003    Finance  Hyderabad    Male  30.0
# 3         E0004  Employee_004         HR     Mumbai    Male  37.0
# 4         E0005  Employee_005      Sales  Bengaluru  Female  39.0
# ..          ...           ...        ...        ...     ...   ...
# 245       E0246  Employee_246  Marketing     Mumbai    Male  41.0
# 246       E0247  Employee_247         IT      Delhi  Female  47.0
# 247       E0248  Employee_248  Marketing  Hyderabad  Female  40.0
# 248       E0249  Employee_249  Marketing      Delhi    Male  38.0
# 249       E0250  Employee_250  Marketing     Mumbai    Male  36.0
#
#      Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 0                   7   69600.0        87400.0                 3.8
# ...

# %% [markdown]
# # **Q19. Missing Salary ko median salary se fill karo.**

# %%
df[df['Salary'].isna()]
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 25        E0026  Employee_026    Finance  Bengaluru  Female  51.0
# 114       E0115  Employee_115         HR  Hyderabad  Female  24.0
# 174       E0175  Employee_175    Finance    Chennai    Male  31.0
# 175       E0176  Employee_176      Sales  Bengaluru  Female  50.0
# 197       E0198  Employee_198  Marketing      Delhi    Male  44.0
# 216       E0217  Employee_217         IT       Pune    Male  28.0
# 225       E0226  Employee_226      Sales  Hyderabad    Male  39.0
#
#      Experience_Years  Salary  Monthly_Sales  Performance_Rating  \
# 25                 15     NaN        34300.0                 3.5
# 114                 1     NaN        39300.0                 3.7
# 174                 2     NaN        17700.0                 3.8
# 175                14     NaN       105200.0                 4.6
# 197                 6     NaN        66100.0                 2.4
# ...

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())

# %%
df[df['Salary'].isna()]
# all NaN value are replace with median of salary
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Department, City, Gender, Age, Experience_Years, Salary, Monthly_Sales, Performance_Rating, Projects_Completed, Attendance_Percent, Joining_Date]
# Index: []

# %% [markdown]
# # **Q20. Missing City ko "Unknown" se fill karo.**

# %%
df[df['City'].isna()]
# Out:
#     Employee_ID          Name Department City Gender   Age  Experience_Years  \
# 28        E0029  Employee_029         HR  NaN   Male  33.0                 6
# 33        E0034  Employee_034  Marketing  NaN   Male  33.0                 1
# 164       E0165  Employee_165      Sales  NaN   Male  48.0                13
# 192       E0193  Employee_193  Marketing  NaN   Male  38.0                11
# 228       E0229  Employee_229  Marketing  NaN   Male  26.0                 3
#
#        Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 28    48500.0        90000.0                 4.1                   1
# 33    46600.0        57600.0                 2.2                   6
# 164  107100.0       155100.0                 4.1                   8
# 192   77000.0        41500.0                 2.9                   4
# 228   52200.0        37800.0                 3.7                   9
#
#      Attendance_Percent Joining_Date
# 28                 87.7   2025-02-15
# ...

# %%
df['City'] = df['City'].fillna("Unknown")

# %%
df[df['City'].isna()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Department, City, Gender, Age, Experience_Years, Salary, Monthly_Sales, Performance_Rating, Projects_Completed, Attendance_Percent, Joining_Date]
# Index: []

# %% [markdown]
# # **Q21. Check karo cleaning ke baad koi missing value bachi hai ya nahi.**

# %%
df.isna().sum()
# ha abhi 3 columns me NaN value hai
# Out:
# Employee_ID           0
# Name                  0
# Department            0
# City                  0
# Gender                0
# Age                   7
# Experience_Years      0
# Salary                0
# Monthly_Sales         8
# Performance_Rating    6
# Projects_Completed    0
# Attendance_Percent    0
# Joining_Date          0
# dtype: int64

# %% [markdown]
# # **Q22. Ek new column banao:Annual_Salary Formula:Salary × 12**

# %%
df['Annual_Salary'] = df['Salary'] * 12

# %%
df.head()
# Out:
#   Employee_ID          Name Department       City  Gender   Age  \
# 0       E0001  Employee_001         IT       Pune    Male  37.0
# 1       E0002  Employee_002  Marketing       Pune  Female  39.0
# 2       E0003  Employee_003    Finance  Hyderabad    Male  30.0
# 3       E0004  Employee_004         HR     Mumbai    Male  37.0
# 4       E0005  Employee_005      Sales  Bengaluru  Female  39.0
#
#    Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 0                 7   69600.0        87400.0                 3.8
# 1                15   94100.0       104800.0                 2.5
# 2                 1   37300.0        56100.0                 3.2
# 3                11   78700.0        37600.0                 3.8
# 4                14  105500.0       148100.0                 3.2
#
#    Projects_Completed  Attendance_Percent Joining_Date  Annual_Salary
# 0                  10                86.1   2018-06-20       835200.0
# ...

# %% [markdown]
# # Q23.Ek new column banao:Sales_Performance
# # Condition:
# # Monthly_Sales >= 100000 → "High"
# # Monthly_Sales < 100000  → "Low"

# %%
df['Sales_Performance'] = np.where(
        df['Monthly_Sales'] >= 100000,'High','Low'
)

# %%
df.head(3)
# Out:
#   Employee_ID          Name Department       City  Gender   Age  \
# 0       E0001  Employee_001         IT       Pune    Male  37.0
# 1       E0002  Employee_002  Marketing       Pune  Female  39.0
# 2       E0003  Employee_003    Finance  Hyderabad    Male  30.0
#
#    Experience_Years   Salary  Monthly_Sales  Performance_Rating  \
# 0                 7  69600.0        87400.0                 3.8
# 1                15  94100.0       104800.0                 2.5
# 2                 1  37300.0        56100.0                 3.2
#
#    Projects_Completed  Attendance_Percent Joining_Date  Annual_Salary  \
# 0                  10                86.1   2018-06-20       835200.0
# 1                   9                98.0   2024-09-22      1129200.0
# 2                   6                91.7   2020-01-10       447600.0
#
#   Sales_Performance
# 0               Low
# 1              High
# 2               Low

# %% [markdown]
# # **Q24.Salary ko ascending order me sort karo.**

# %%
np.sort(df['Salary'])
# Out:
# array([ 25000.,  27800.,  28100.,  28300.,  28400.,  28800.,  29600.,
#         31200.,  31200.,  32000.,  32100.,  32600.,  33900.,  35400.,
#         36300.,  36800.,  37200.,  37300.,  37400.,  37600.,  38600.,
#         38800.,  39800.,  39800.,  40400.,  40900.,  41100.,  41800.,
#         42000.,  43000.,  43100.,  43300.,  43800.,  44200.,  45000.,
#         45100.,  45500.,  45500.,  45500.,  45800.,  45900.,  46000.,
#         46200.,  46600.,  46600.,  46800.,  46800.,  47000.,  47800.,
#         48000.,  48200.,  48300.,  48300.,  48300.,  48400.,  48500.,
#         49100.,  49100.,  49600.,  49600.,  49800.,  50200.,  50300.,
#         50800.,  50800.,  51000.,  51400.,  51800.,  52200.,  52200.,
#         52400.,  52700.,  53900.,  54400.,  55900.,  56600.,  57000.,
#         57100.,  57500.,  57600.,  57800.,  58000.,  58100.,  58100.,
#         58600.,  59000.,  59000.,  59500.,  59800.,  60600.,  60800.,
# ...

# %%
df.sort_values('Salary').head(3)
# Out:
#     Employee_ID          Name Department       City Gender   Age  \
# 62        E0063  Employee_063  Marketing  Hyderabad   Male  23.0
# 203       E0204  Employee_204  Marketing  Bengaluru   Male  38.0
# 70        E0071  Employee_071    Finance       Pune   Male  30.0
#
#      Experience_Years   Salary  Monthly_Sales  Performance_Rating  \
# 62                  0  25000.0       109300.0                 NaN
# 203                 0  27800.0        75600.0                 NaN
# 70                  0  28100.0        42600.0                 3.0
#
#      Projects_Completed  Attendance_Percent Joining_Date  Annual_Salary  \
# 62                    3                86.6   2019-03-10       300000.0
# 203                   3                88.5   2018-11-23       333600.0
# 70                    6                87.8   2018-01-26       337200.0
#
#     Sales_Performance
# 62               High
# 203               Low
# 70                Low

# %%
df['Salary'].sort_values()
# Out:
# 62      25000.0
# 203     27800.0
# 70      28100.0
# 128     28300.0
# 149     28400.0
#          ...
# 248    110100.0
# 126    110700.0
# 246    111000.0
# 144    111400.0
# 230    113600.0
# Name: Salary, Length: 253, dtype: float64

# %% [markdown]
# # **Q25.Top 10 highest-paid employees find karo.**

# %%
df.sort_values('Salary',ascending=False).head(10)
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 230       E0231  Employee_231    Finance  Hyderabad    Male  54.0
# 144       E0145  Employee_145         IT  Bengaluru  Female  47.0
# 246       E0247  Employee_247         IT      Delhi  Female  47.0
# 126       E0127  Employee_127  Marketing  Bengaluru    Male  39.0
# 248       E0249  Employee_249  Marketing      Delhi    Male  38.0
# 139       E0140  Employee_140  Marketing  Bengaluru  Female  41.0
# 164       E0165  Employee_165      Sales    Unknown    Male  48.0
# 102       E0103  Employee_103         IT       Pune  Female  44.0
# 83        E0084  Employee_084      Sales      Delhi    Male  43.0
# 4         E0005  Employee_005      Sales  Bengaluru  Female  39.0
#
#      Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 230                15  113600.0        45100.0                 2.5
# 144                15  111400.0        31800.0                 3.8
# ...

# %% [markdown]
# # **Q26. Top 10 employees by Monthly_Sales find karo.**

# %%
df.sort_values('Monthly_Sales',ascending=False).head(10)
# Out:
#     Employee_ID          Name Department       City  Gender   Age  \
# 128       E0129  Employee_129      Sales       Pune    Male  25.0
# 49        E0050  Employee_050      Sales       Pune    Male  52.0
# 148       E0149  Employee_149      Sales      Delhi  Female  42.0
# 15        E0016  Employee_016      Sales  Bengaluru    Male  43.0
# 173       E0174  Employee_174      Sales      Delhi    Male  28.0
# 40        E0041  Employee_041      Sales     Mumbai  Female  32.0
# 98        E0099  Employee_099      Sales    Chennai    Male  30.0
# 6         E0007  Employee_007      Sales  Bengaluru    Male  29.0
# 205       E0206  Employee_206      Sales  Hyderabad    Male  25.0
# 57        E0058  Employee_058      Sales    Chennai  Female  44.0
#
#      Experience_Years   Salary  Monthly_Sales  Performance_Rating  \
# 128                 0  28300.0       223500.0                 4.0
# 49                 14  97800.0       213900.0                 3.4
# ...

# %% [markdown]
# # **Q27.Joining_Date ko datetime me convert karo.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         253 non-null    object
#  1   Name                253 non-null    object
#  2   Department          253 non-null    object
#  3   City                253 non-null    object
#  4   Gender              253 non-null    object
#  5   Age                 246 non-null    float64
#  6   Experience_Years    253 non-null    int64
#  7   Salary              253 non-null    float64
#  8   Monthly_Sales       245 non-null    float64
#  9   Performance_Rating  247 non-null    float64
#  10  Projects_Completed  253 non-null    int64
#  11  Attendance_Percent  253 non-null    float64
#  12  Joining_Date        253 non-null    object
#  13  Annual_Salary       253 non-null    float64
#  14  Sales_Performance   253 non-null    object
# ...

# %%
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         253 non-null    object
#  1   Name                253 non-null    object
#  2   Department          253 non-null    object
#  3   City                253 non-null    object
#  4   Gender              253 non-null    object
#  5   Age                 246 non-null    float64
#  6   Experience_Years    253 non-null    int64
#  7   Salary              253 non-null    float64
#  8   Monthly_Sales       245 non-null    float64
#  9   Performance_Rating  247 non-null    float64
#  10  Projects_Completed  253 non-null    int64
#  11  Attendance_Percent  253 non-null    float64
#  12  Joining_Date        253 non-null    datetime64[ns]
#  13  Annual_Salary       253 non-null    float64
#  14  Sales_Performance   253 non-null    object
# ...

# %% [markdown]
# # **Q28. Joining year ka new column banao:**

# %%
df['Joining_Date'].dt.year
# Out:
# 0      2018
# 1      2024
# 2      2020
# 3      2021
# 4      2025
#        ...
# 248    2024
# 249    2024
# 250    2022
# 251    2019
# 252    2020
# Name: Joining_Date, Length: 253, dtype: int32

# %%
df['Joining_year'] = df['Joining_Date'].dt.year

# %%
df.head(3)
# Out:
#   Employee_ID          Name Department       City  Gender   Age  \
# 0       E0001  Employee_001         IT       Pune    Male  37.0
# 1       E0002  Employee_002  Marketing       Pune  Female  39.0
# 2       E0003  Employee_003    Finance  Hyderabad    Male  30.0
#
#    Experience_Years   Salary  Monthly_Sales  Performance_Rating  \
# 0                 7  69600.0        87400.0                 3.8
# 1                15  94100.0       104800.0                 2.5
# 2                 1  37300.0        56100.0                 3.2
#
#    Projects_Completed  Attendance_Percent Joining_Date  Annual_Salary  \
# 0                  10                86.1   2018-06-20       835200.0
# 1                   9                98.0   2024-09-22      1129200.0
# 2                   6                91.7   2020-01-10       447600.0
#
#   Sales_Performance  Joining_year
# 0               Low          2018
# 1              High          2024
# 2               Low          2020

# %% [markdown]
# ## **GroupBy + Analysis**

# %% [markdown]
# # **Q29. Department-wise average salary find karo.**

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance      71833.333333
# HR           66706.756757
# IT           75254.081633
# Marketing    62341.666667
# Sales        70766.233766
# Name: Salary, dtype: float64

# %% [markdown]
# # **Q30. Department-wise total sales find karo.**

# %%
df.groupby('Department')['Monthly_Sales'].sum()
# Out:
# Department
# Finance      2148700.0
# HR           2557000.0
# IT           3476900.0
# Marketing    3974200.0
# Sales        9488100.0
# Name: Monthly_Sales, dtype: float64

# %% [markdown]
# # **Q31. City-wise employee count find karo.**

# %%
df.head(2)
# Out:
#   Employee_ID          Name Department  City  Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune    Male  37.0                 7
# 1       E0002  Employee_002  Marketing  Pune  Female  39.0                15
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
# 1  94100.0       104800.0                 2.5                   9
#
#    Attendance_Percent Joining_Date  Annual_Salary Sales_Performance  \
# 0                86.1   2018-06-20       835200.0               Low
# 1                98.0   2024-09-22      1129200.0              High
#
#    Joining_year
# 0          2018
# 1          2024

# %%
df.groupby('City')['Employee_ID'].count()
# Out:
# City
# Bengaluru    50
# Chennai      36
# Delhi        42
# Hyderabad    42
# Mumbai       33
# Pune         45
# Unknown       5
# Name: Employee_ID, dtype: int64

# %% [markdown]
# # **Q32. Department-wise average performance rating find karo.**

# %%
df.groupby("Department")['Performance_Rating'].mean()
# Out:
# Department
# Finance      3.602857
# HR           3.716216
# IT           3.581250
# Marketing    3.407692
# Sales        3.617333
# Name: Performance_Rating, dtype: float64

# %% [markdown]
# # **Q33. Department-wise average attendance find karo.**

# %%
df.groupby("Department")['Attendance_Percent'].mean()
# Out:
# Department
# Finance      87.102778
# HR           88.127027
# IT           88.177551
# Marketing    87.405556
# Sales        87.033766
# Name: Attendance_Percent, dtype: float64

# %% [markdown]
# # **Q34. Kaunsa department highest average salary deta hai?**

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date  Annual_Salary Sales_Performance  \
# 0                86.1   2018-06-20       835200.0               Low
#
#    Joining_year
# 0          2018

# %%
df.groupby("Department")['Salary'].mean()
# IT department sab se jada average salary deta hai
# Out:
# Department
# Finance      71833.333333
# HR           66706.756757
# IT           75254.081633
# Marketing    62341.666667
# Sales        70766.233766
# Name: Salary, dtype: float64

# %%
df.groupby("Department")['Salary'].mean().idxmax()
# IT department sab se jada average salary deta hai
# Out:
# 'IT'

# %% [markdown]
# # **Q35. Kaunsa department highest total sales generate karta hai?**

# %%
df.groupby("Department")['Monthly_Sales'].sum()
# sales department sab se jada sale generate karta hai
# Out:
# Department
# Finance      2148700.0
# HR           2557000.0
# IT           3476900.0
# Marketing    3974200.0
# Sales        9488100.0
# Name: Monthly_Sales, dtype: float64

# %%
df.groupby("Department")['Monthly_Sales'].sum().idxmax()
# sales department sab se jada sale generate karta hai
# Out:
# 'Sales'

# %% [markdown]
# # **Q36. Kaunsi city me sabse zyada employees hain?**

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date  Annual_Salary Sales_Performance  \
# 0                86.1   2018-06-20       835200.0               Low
#
#    Joining_year
# 0          2018

# %%
df.groupby('City')['Employee_ID'].count().idxmax()
# Bengaluru me sab se jada employees hai
# Out:
# 'Bengaluru'

# %% [markdown]
# # **Q37. Gender-wise average salary compare karo.**

# %%
df.groupby('Gender')['Salary'].mean()
# Out:
# Gender
# Female    72337.610619
# Male      67020.714286
# Name: Salary, dtype: float64

# %% [markdown]
# # **Q38.Department + Gender ke basis par average salary find karo**

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date  Annual_Salary Sales_Performance  \
# 0                86.1   2018-06-20       835200.0               Low
#
#    Joining_year
# 0          2018

# %%
df.groupby(['Department','Gender'])['Salary'].mean()
# Out:
# Department  Gender
# Finance     Female    72596.428571
#             Male      71347.727273
# HR          Female    68975.000000
#             Male      64557.894737
# IT          Female    82945.833333
#             Male      67870.000000
# Marketing   Female    65830.000000
#             Male      60289.705882
# Sales       Female    70512.162162
#             Male      71001.250000
# Name: Salary, dtype: float64

# %%
df.groupby(['Department','Gender'])['Salary'].mean().idxmax()
# matlab IT me sab se jada salery hai or female ki
# Out:
# ('IT', 'Female')

# %% [markdown]
# # **NumPy + Pandas Together**

# %% [markdown]
# # **Q39.Salary ka NumPy array banao aur:Median se zyada salary wale employees ki count find karo.**

# %%
a = df['Salary'].to_numpy()
np.median(a)
# Out:
# np.float64(69850.0)

# %%
np.sum(a > np.median(a))
# Out:
# np.int64(123)

# %% [markdown]
# # Q40. Monthly sales ka mean NumPy se calculate karo.
# # Phir Pandas se same result calculate karo.

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date  Annual_Salary Sales_Performance  \
# 0                86.1   2018-06-20       835200.0               Low
#
#    Joining_year
# 0          2018

# %%
np.mean(df['Monthly_Sales'])
# Out:
# np.float64(88346.5306122449)

# %%
df['Monthly_Sales'].mean()
# Out:
# np.float64(88346.5306122449)

# %% [markdown]
# # Q41. NumPy ka use karke identify karo:
# High Sales = Monthly_Sales > mean sales
# Phir Pandas DataFrame me un employees ko filter karo.

# %%
sales = df['Monthly_Sales'].to_numpy()

# %%
high_sales = sales > np.mean(sales)
df[high_sales]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Department, City, Gender, Age, Experience_Years, Salary, Monthly_Sales, Performance_Rating, Projects_Completed, Attendance_Percent, Joining_Date, Annual_Salary, Sales_Performance, Joining_year]
# Index: []

# %% [markdown]
# # Q42. Performance rating ka:
# mean
# median
# std
# min
# max

# %%
print(np.mean(df['Performance_Rating']))
print(np.median(df['Performance_Rating']))
print(np.std(df['Performance_Rating']))
print(np.min(df['Performance_Rating']))
print(np.max(df['Performance_Rating']))
# Out:
# 3.5789473684210527
# nan
# 0.602862692808001
# 1.4
# 4.9

# %% [markdown]
# # **Q43. Department-wise employee count ka bar chart banao.**

# %%
dept_count = df.groupby('Department')['Employee_ID'].count()

# %%
plt.bar(dept_count.index, dept_count.values)
plt.show()

# %% [markdown]
# # **Q44. Salary ka histogram banao.**

# %%
hist_salary = df['Salary'].to_numpy()

# %%
plt.hist(hist_salary,bins=10)
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.title("Sales distiburion")
plt.show()

# %% [markdown]
# # Q45.Experience vs Salary ka scatter plot banao.
# Question:
# Kya experience badhne ke saath salary generally increase hoti hai?

# %%
exp = df['Experience_Years'].to_numpy()
sal = df['Salary'].to_numpy()

# %%
plt.scatter(x=exp,y=sal,c='r',marker='D',s=50,alpha=0.6,edgecolors='black')
plt.xlabel('Experience Years')
plt.ylabel('salary')
plt.title('Salary vs Experience')
plt.show()

# %% [markdown]
# # **Q46. Joining year ke according employees ka count line chart me dikhao.**

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date  Annual_Salary Sales_Performance  \
# 0                86.1   2018-06-20       835200.0               Low
#
#    Joining_year
# 0          2018

# %%
joi = df['Joining_Date'].dt.year.to_numpy()
year_count = pd.Series(joi).value_counts().sort_index()

# %%
plt.plot(year_count.index, year_count.values, marker='o')
plt.show()

# %% [markdown]
# # **Q47. Department-wise average salary ka bar chart banao.**

# %%
avg_salary = df.groupby('Department')['Salary'].mean()

plt.bar(x=avg_salary.index, height=avg_salary.values)

plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.title('Department-wise Average Salary')

plt.show()

# %% [markdown]
# # **Seaborn**

# %% [markdown]
# Q48.Department vs Salary ka boxplot banao.
# Question:
# Kis department me salary variation zyada hai?

# %%
dep = df['Department'].to_numpy()
sal = df['Salary'].to_numpy()

sns.boxplot(x=dep,y = sal)
plt.xlabel('Department')
plt.ylabel('Salary')
plt.title('Salary Variation by Department')
plt.show()

# %%
sns.boxplot(x=df['Department'], y=df['Salary'])
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# # **Q49. Department vs Performance Rating ka boxplot banao.**

# %%
sns.boxplot(x=df['Department'], y=df['Performance_Rating'])
# Out:
# <Axes: xlabel='Department', ylabel='Performance_Rating'>

# %% [markdown]
# # **Q50. Gender vs Salary ka boxplot banao.**

# %%
sns.boxplot(x=df['Gender'],y = df['Salary'])
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %% [markdown]
# # **Q51. Experience aur Salary ka Seaborn scatterplot banao.**

# %%
sns.scatterplot(x=df['Experience_Years'],y=df['Salary'])
# Out:
# <Axes: xlabel='Experience_Years', ylabel='Salary'>

# %% [markdown]
# # **Q52. Salary, Sales, Experience aur Rating ka heatmap/correlation matrix banao.**

# %%
s =df[['Salary', 'Monthly_Sales', 'Experience_Years', 'Performance_Rating']].corr()

# %%
sns.heatmap(s, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Q53. Find the top 5 employees who have:
# High Salary
# AND
# High Performance Rating
# AND
# High Sales

# %%
df.head(1)
# Out:
#   Employee_ID          Name Department  City Gender   Age  Experience_Years  \
# 0       E0001  Employee_001         IT  Pune   Male  37.0                 7
#
#     Salary  Monthly_Sales  Performance_Rating  Projects_Completed  \
# 0  69600.0        87400.0                 3.8                  10
#
#    Attendance_Percent Joining_Date  Annual_Salary Sales_Performance  \
# 0                86.1   2018-06-20       835200.0               Low
#
#    Joining_year
# 0          2018

# %%
High_Salary = df['Salary'] > df['Salary'].median()
High_Performance_Rating = df['Performance_Rating'] >= 4
High_Sales = df['Monthly_Sales'] > df['Monthly_Sales'].mean()

# %%
result = df[High_Salary & High_Performance_Rating & High_Sales]

# %%
df.head(5)
# Out:
#   Employee_ID          Name Department       City  Gender   Age  \
# 0       E0001  Employee_001         IT       Pune    Male  37.0
# 1       E0002  Employee_002  Marketing       Pune  Female  39.0
# 2       E0003  Employee_003    Finance  Hyderabad    Male  30.0
# 3       E0004  Employee_004         HR     Mumbai    Male  37.0
# 4       E0005  Employee_005      Sales  Bengaluru  Female  39.0
#
#    Experience_Years    Salary  Monthly_Sales  Performance_Rating  \
# 0                 7   69600.0        87400.0                 3.8
# 1                15   94100.0       104800.0                 2.5
# 2                 1   37300.0        56100.0                 3.2
# 3                11   78700.0        37600.0                 3.8
# 4                14  105500.0       148100.0                 3.2
#
#    Projects_Completed  Attendance_Percent Joining_Date  Annual_Salary  \
# 0                  10                86.1   2018-06-20       835200.0
# ...

# %% [markdown]
# Q54.Find the department where:
# Average Salary is highest
# BUT
# Average Performance Rating is lowest

# %%
avg_salary = df.groupby('Department')['Salary'].mean()
avg_rating = df.groupby('Department')['Performance_Rating'].mean()

# %%
print(avg_salary.idxmax())
print(avg_rating.idxmin())
# Out:
# IT
# Marketing
