# %% [markdown]
# # List Datastructure

# %%
l =[] # this is a empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 l.append(20,30)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [10,3.4,"ram",True,3+5j]
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j)]

# %%
l1.append([2,3,4])

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# [10, 20, 30, 40, 50, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 2490213668032
# 2490214104576

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# [10, 20, 30, 40, 50, 10]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# []

# %%
del l3

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 3
#       1 print(l)
#       2 print(l1)
# ----> 3 print(l3)
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l.count(20)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l.index(10)
# Out:
# 0

# %%
l1.index("ram")
# Out:
# 2

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l1[3:]
# Out:
# [True, (3+5j), [2, 3, 4]]

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l1[2]
# Out:
# 'ram'

# %%
print(l1[2][0])
print(l1[2][1])
print(l1[2][2])
# Out:
# r
# a
# m

# %%
l1
# Out:
# [10, 3.4, 'ram', True, (3+5j), [2, 3, 4]]

# %%
l1[0]=100

# %%
l1
# Out:
# [100, 3.4, 'ram', True, (3+5j), [2, 3, 4]]
