# %% [markdown]
# # Variable in python

# %% [markdown]
# ### Syntex : variable_name = value

# %%
num = 10 
num
# Out:
# 10

# %%
num2 = 33
num2
# Out:
# 33

# %% [markdown]
# ## Rule for variables name

# %% [markdown]
# #### Must start with a letter (a-z, A-Z) or an underscore (_).
# #### Can contain letters, digits (0-9), and underscores, but cannot start with a digit.
# #### Case-sensitive: age, Age, and AGE are different variables.
# #### Cannot be a Python keyword (e.g., True, False, if, for, class, etc.).

# %%
name = 'Varnit Singh'
name
# Out:
# 'Varnit Singh'

# %%
f = 7.8
f
# Out:
# 7.8

# %% [markdown]
# ## To know the list of keywords

# %%
import keyword
print(end=" ")
print(keyword.kwlist)
print("This are keywords in python",len(keyword.kwlist))
# Out:
#  ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# This are keywords in python 35

# %%
5j = 5   # can not start variable name with latter
5j
# Out:
#   Cell In[11], line 1
#     5j = 5
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# Both age are different / and it is called case sensitivity.
age = 34
Age = 35
print(age)
print(Age)
# Out:
# 34
# 35
