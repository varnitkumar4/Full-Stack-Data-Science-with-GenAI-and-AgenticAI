# %% [markdown]
# # **List**

# %%
l = [1,2,3,4,5]
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l[0]
# Out:
# 1

# %%
l[0]=5

# %%
l
# Out:
# [5, 2, 3, 4, 5]

# %%
l2= ['ram',5,'True',5.3,5+4j]
l2
# Out:
# ['ram', 5, 'True', 5.3, (5+4j)]

# %%
l2[4]
# Out:
# (5+4j)

# %%
l2[1:3]
# Out:
# [5, 'True']

# %%
l2[-3:-1]
# Out:
# ['True', 5.3]

# %%
l2[-1:-3]
# Out:
# []

# %%
print(type(l))
type(l2)
# Out:
# <class 'list'>
# list

# %%
l3 = list(("ram",5,6.4,'True'))
print(l3)
print(type(l3))
# Out:
# ['ram', 5, 6.4, 'True']
# <class 'list'>

# %%
l
# Out:
# [5, 2, 3, 4, 5]

# %%
if 5 in l:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
if 6 in l:
  print("y")

# %%
if 9 in l:
  print("y")
else:
  print('n')
# Out:
# n

# %%
# change range value
l
# Out:
# [5, 2, 3, 4, 5]

# %%
l[1:4] = [9,10,11]
l
# Out:
# [5, 9, 10, 11, 5]

# %%
l2
# Out:
# ['ram', 5, 'True', 5.3, (5+4j)]

# %%
l2.insert(1,"laxman")
l2
# Out:
# ['ram', 'laxman', 5, 'True', 5.3, (5+4j)]

# %%
l4 = ["raja",'ram','chandra']
l5 = ['shree','kisori','radha','rani']
l4.extend(l5)
print(l4)
# Out:
# ['raja', 'ram', 'chandra', 'shree', 'kisori', 'radha', 'rani']

# %%
l5
# Out:
# ['shree', 'kisori', 'radha', 'rani']

# %%
l5.remove('rani')
l5
# Out:
# ['shree', 'kisori', 'radha']

# %%
l5
# Out:
# ['shree', 'kisori', 'radha']

# %%
l5.pop(0) # specific index element remove
# Out:
# 'shree'

# %%
l5
# Out:
# ['kisori', 'radha']

# %%
l5
# Out:
# ['kisori', 'radha']

# %%
l5.clear() # clear the all element from the list
l5
# Out:
# []

# %%
l4
# Out:
# ['raja', 'ram', 'chandra', 'shree', 'kisori', 'radha', 'rani']

# %%
for x in l4:
  print(x)
# Out:
# raja
# ram
# chandra
# shree
# kisori
# radha
# rani

# %%
for i in range(len(l4)):
    print(l4[i])
# Out:
# raja
# ram
# chandra
# shree
# kisori
# radha
# rani

# %%
l4
# Out:
# ['raja', 'ram', 'chandra', 'shree', 'kisori', 'radha', 'rani']

# %%
[print(x) for x in l4]
# Out:
# raja
# ram
# chandra
# shree
# kisori
# radha
# rani
# [None, None, None, None, None, None, None]

# %%
fruits= ['apple','orange','banana','guava','kiwi']
newlist = []
for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'orange', 'banana', 'guava']

# %%
newlist = [x for x in fruits if "a" in x]
print(newlist)
# Out:
# ['apple', 'orange', 'banana', 'guava']

# %%
l4
# Out:
# ['raja', 'ram', 'chandra', 'shree', 'kisori', 'radha', 'rani']

# %%
l4.sort()
l4
# Out:
# ['chandra', 'kisori', 'radha', 'raja', 'ram', 'rani', 'shree']

# %%
l
# Out:
# [5, 9, 10, 11, 5]

# %%
l.sort()
l
# Out:
# [5, 5, 9, 10, 11]

# %%
l.sort(reverse=True)
l
# Out:
# [11, 10, 9, 5, 5]

# %%
thislist = [5,4,7,1,0]
thislist.sort()
print(thislist)
# Out:
# [0, 1, 4, 5, 7]

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"] # first sort capital letter then small later
thislist.sort()
print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
l =["banana", "Orange", "Kiwi", "cherry"]
l.sort(key = str.lower)
print(l)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %% [markdown]
# # **Tuple**

# %%
tup = ('ram',8,5,7,'ahua')
tup
# Out:
# ('ram', 8, 5, 7, 'ahua')

# %%
type(tup)
# Out:
# tuple

# %%
t = tuple(('ram','shyam'))
print(t)
print(type(t))
# Out:
# ('ram', 'shyam')
# <class 'tuple'>

# %%
t[0]
# Out:
# 'ram'

# %%
t[-1]
# Out:
# 'shyam'

# %%
t2 = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
t2
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
t2[:6]
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon')

# %%
t2[1:3]
# Out:
# ('banana', 'cherry')

# %%
if "kiwi" in t2:
  print('yes')
# Out:
# yes

# %%
print(t2)
l = list(t2)
l[2]='ram'
t2 = tuple(l)
print(t2)
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')
# ('apple', 'banana', 'ram', 'orange', 'kiwi', 'melon', 'mango')

# %%
for i in t2:
  print(i)
# Out:
# apple
# banana
# ram
# orange
# kiwi
# melon
# mango

# %% [markdown]
# # **Sets**

# %%
s = {2,3,4,5,6}
s
# Out:
# {2, 3, 4, 5, 6}

# %%
type(s)
# Out:
# set

# %%
s2 = {0,6,2,2,2,3,4,4,5,6,6}
s2
# Out:
# {0, 2, 3, 4, 5, 6}

# %%
s3 = set((4,1,2,1,1,0,5))
s3
# Out:
# {0, 1, 2, 4, 5}

# %%
type(s3)
# Out:
# set

# %%
s2
# Out:
# {0, 2, 3, 4, 5, 6}

# %%
for i in s2:
  print(i)
# Out:
# 0
# 2
# 3
# 4
# 5
# 6

# %%
print(3 not in s2)
# Out:
# False

# %%
print(11 not in s2)
# Out:
# True

# %%
print(3 in s2)
# Out:
# True

# %%
s3
# Out:
# {0, 1, 2, 4, 5}

# %%
s3.add(9)

# %%
s3
# Out:
# {0, 1, 2, 4, 5, 9}

# %%
s4 = {'ram','shyam','laxam','bharat'}
s5 = {3,4,5,2,1,6,7}
print("s4: ",s4)
print("s5: ",s5)
s4.update(s5)
print("s4: ",s4)
# Out:
# s4:  {'bharat', 'shyam', 'laxam', 'ram'}
# s5:  {1, 2, 3, 4, 5, 6, 7}
# s4:  {'bharat', 1, 2, 3, 4, 5, 6, 'ram', 7, 'laxam', 'shyam'}

# %%
s4
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'bharat', 'laxam', 'ram', 'shyam'}

# %%
s4.remove(5)

# %%
s4
# Out:
# {1, 2, 3, 4, 6, 7, 'bharat', 'laxam', 'ram', 'shyam'}

# %%
for i in s4:
  print(i)
# Out:
# bharat
# 1
# 2
# 3
# 4
# 6
# ram
# 7
# laxam
# shyam

# %% [markdown]
# # ***Dictionary***

# %%
dicto = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(dicto)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2000

}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2000}

# %%
len(thisdict)
# Out:
# 3

# %%
di = {
    "ram" : 23,
    "shayam" : 34,
    'radha' : 32,
    "laxman" : 21,
    'vill' : ['muz','sit','lack','bang']
}

print(di)
# Out:
# {'ram': 23, 'shayam': 34, 'radha': 32, 'laxman': 21, 'vill': ['muz', 'sit', 'lack', 'bang']}

# %%
a = di.keys()

# %%
a
# Out:
# dict_keys(['ram', 'shayam', 'radha', 'laxman', 'vill'])

# %%
di.keys()
# Out:
# dict_keys(['ram', 'shayam', 'radha', 'laxman', 'vill'])

# %%
di['hanuman'] = 20

# %%
di
# Out:
# {'ram': 23,
#  'shayam': 34,
#  'radha': 32,
#  'laxman': 21,
#  'vill': ['muz', 'sit', 'lack', 'bang'],
#  'hanuman': 20}

# %%
di.values()
# Out:
# dict_values([23, 34, 32, 21, ['muz', 'sit', 'lack', 'bang'], 20])

# %%
di.items()
# Out:
# dict_items([('ram', 23), ('shayam', 34), ('radha', 32), ('laxman', 21), ('vill', ['muz', 'sit', 'lack', 'bang']), ('hanuman', 20)])

# %%
if "ram" in di:
  print("yes")
# Out:
# yes

# %%
if "karan" in di :
  print('yes')
else:
  print("no")
# Out:
# no

# %%
# chnage value
print(di)
di['ram'] = 25
print(di)
# Out:
# {'ram': 23, 'shayam': 34, 'radha': 32, 'laxman': 21, 'vill': ['muz', 'sit', 'lack', 'bang'], 'hanuman': 20}
# {'ram': 25, 'shayam': 34, 'radha': 32, 'laxman': 21, 'vill': ['muz', 'sit', 'lack', 'bang'], 'hanuman': 20}

# %%
di
# Out:
# {'ram': 25,
#  'shayam': 34,
#  'radha': 32,
#  'laxman': 21,
#  'vill': ['muz', 'sit', 'lack', 'bang'],
#  'hanuman': 20}

# %%
di.pop("vill")
# Out:
# ['muz', 'sit', 'lack', 'bang']

# %%
di
# Out:
# {'ram': 25, 'shayam': 34, 'radha': 32, 'laxman': 21, 'hanuman': 20}

# %%
di.popitem()
# Out:
# ('hanuman', 20)

# %%
di.popitem()
# Out:
# ('laxman', 21)

# %%
di
# Out:
# {'ram': 25, 'shayam': 34, 'radha': 32}

# %%
for x in di:
  print(x)
# Out:
# ram
# shayam
# radha

# %%
for a,b in enumerate(range(2,13)):
  print(a,"-",b)
# Out:
# 0 - 2
# 1 - 3
# 2 - 4
# 3 - 5
# 4 - 6
# 5 - 7
# 6 - 8
# 7 - 9
# 8 - 10
# 9 - 11
# 10 - 12
