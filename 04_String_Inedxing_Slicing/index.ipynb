# %% [markdown]
# # String Indexing

# %% [markdown]
# #### 1 - Forward index
# #### 2 - Backward index

# %%
s = "Forward index"
s
# Out:
# 'Forward index'

# %% [markdown]
# ### 1 - Forward index

# %%
s[0]
# Out:
# 'F'

# %%
s[1]
# Out:
# 'o'

# %%
s[5]
# Out:
# 'r'

# %%
s[15]  # index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s[15]
#
# IndexError: string index out of range

# %% [markdown]
# ### 2 - Backward Indexing

# %%
s1 = "Backward indexing"
s1
# Out:
# 'Backward indexing'

# %%
s1[-1]
# Out:
# 'g'

# %%
s1[-2]
# Out:
# 'n'

# %%
s1[-5]
# Out:
# 'e'
