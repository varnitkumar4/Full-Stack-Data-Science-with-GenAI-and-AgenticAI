# %% [markdown]
# # String in python

# %%
name = "Varnit Singh"
name
# Out:
# 'Varnit Singh'

# %%
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])
print(name[6])
print(name[7])
print(name[8])
print(name[9])
print(name[10])
print(name[11])
# Out:
# V
# a
# r
# n
# i
# t
#
# S
# i
# n
# g
# h

# %%
print(name[:])
print(name[3:])
print(name[:6])
print(name[3:5])
print(name[4:8])
# Out:
# Varnit Singh
# nit Singh
# Varnit
# ni
# it S

# %%
print(name[:])
print(name[:-4])
print(name[-7:-1])
print(name[-1:])
print(name[:-1])
print(name[::-1])
print(name[-7:-5])
print(name[:])
# Out:
# Varnit Singh
# Varnit S
# t Sing
# h
# Varnit Sing
# hgniS tinraV
# t
# Varnit Singh
