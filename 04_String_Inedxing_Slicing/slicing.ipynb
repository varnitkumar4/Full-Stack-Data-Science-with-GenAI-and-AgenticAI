# %% [markdown]
# # Index Slicing

# %%
s = "Varnit Singh"
s
# Out:
# 'Varnit Singh'

# %%
s[:]
# Out:
# 'Varnit Singh'

# %%
s[1:]
# Out:
# 'arnit Singh'

# %%
s[:8]
# Out:
# 'Varnit S'

# %%
s[:6]
# Out:
# 'Varnit'

# %% [markdown]
# # Backward slicing

# %%
s[-1]
# Out:
# 'h'

# %%
s[0::2]
# Out:
# 'Vri ig'

# %%
s[0:13:3]

# 0 is starting index 
# 13 last index
# 3 is step -> means 3 step to jump
# Out:
# 'Vn n'

# %%
s[-13:-1:2]
# Out:
# 'Vri ig'
