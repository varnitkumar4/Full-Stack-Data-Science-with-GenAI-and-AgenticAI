# %% [markdown]
# ### Binary

# %%
bin(56)
# Out:
# '0b111000'

# %%
int(0b111000)
# Out:
# 56

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %% [markdown]
# ### octal

# %%
oct(25) # convert number to octal number system
# Out:
# '0o31'

# %%
int(0o31) # convert octal to number
# Out:
# 25

# %%
oct(78)
# Out:
# '0o116'

# %% [markdown]
# ### hexadecimal

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(2)
# Out:
# '0x2'

# %%
hex(8)
# Out:
# '0x8'

# %%
hex(9)
# Out:
# '0x9'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(11)
# Out:
# '0xb'

# %%
hex(12)
# Out:
# '0xc'

# %%
hex(13)
# Out:
# '0xd'

# %%
int(0xd)
# Out:
# 13

# %%
int(0x19)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'
